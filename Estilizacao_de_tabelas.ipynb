# %% [markdown]
# # Coleta e preparação de dados

# %%
# !pip install pandas==2.0.0
# Out:
# Collecting pandas==2.0.0
#   Downloading pandas-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.0) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.0) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.0) (1.16.0)
# Downloading pandas-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 55.6 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 2.0.0 which is incompatible.
# Successfully installed pandas-2.0.0

# %%
import pandas as pd

df = pd.read_csv('/content/relatorio_vendas.csv')
df
# Out:
#      data_pedido      modo_envio       nome_cliente segmento_cliente
# 0     2018-11-09       Econômica    Thiago Silveira              B2C  \
# 1     2018-11-09       Econômica    Thiago Silveira              B2C
# 2     2018-06-13       Econômica      Giovanna Lima              B2B
# 3     2017-10-12  Entrega padrão  Ana Júlia da Cruz              B2C
# 4     2017-10-12  Entrega padrão  Ana Júlia da Cruz              B2C
# ...          ...             ...                ...              ...
# 8935  2018-09-30  Entrega padrão     Enrique Santos              B2C
# 8936  2019-11-18  Entrega padrão    Heitor Silveira              B2B
# 8937  2019-11-18  Entrega padrão    Heitor Silveira              B2B
# 8938  2016-01-22       Econômica      Isabel Araújo              B2C
# 8939  2019-05-05       Econômica   Esther Rodrigues              B2C
#
#               cidade               estado    regiao             departamento
# 0     Ribeirão Preto            São Paulo   Sudeste  Materiais de construção  \
# 1     Ribeirão Preto            São Paulo   Sudeste  Materiais de construção
# 2     Rio de Janeiro       Rio de Janeiro   Sudeste  Jardinagem e paisagismo
# 3      Foz do Iguaçu               Paraná       Sul  Materiais de construção
# 4      Foz do Iguaçu               Paraná       Sul  Jardinagem e paisagismo
# ...              ...                  ...       ...                      ...
# 8935  Rio de Janeiro       Rio de Janeiro   Sudeste               Automotivo
# 8936          Jequié                Bahia  Nordeste               Automotivo
# 8937          Jequié                Bahia  Nordeste               Automotivo
# 8938     João Pessoa              Paraíba  Nordeste  Materiais de construção
# 8939         Mossoró  Rio Grande do Norte  Nordeste  Jardinagem e paisagismo
#
#                    tipo_produto   vendas  quantidade    lucro
# 0                  encanamentos   890.66           2   142.51
# 1                   ferramentas  2488.60           3   746.58
# 2                      sementes    49.71           2    23.36
# 3     materiais de revestimento  3255.76           5 -1302.31
# 4                         vasos    76.05           2     8.56
# ...                         ...      ...         ...      ...
# 8935    ferramentas automotivas   123.22           1    51.75
# 8936    ferramentas automotivas   271.97           1    97.91
# 8937                      pneus   700.74           5   189.20
# 8938                 iluminação    85.84           3    13.95
# 8939     mobiliário de exterior   826.74           2   248.02
#
# [8940 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8940 entries, 0 to 8939
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_pedido       8940 non-null   object
#  1   modo_envio        8940 non-null   object
#  2   nome_cliente      8940 non-null   object
#  3   segmento_cliente  8940 non-null   object
#  4   cidade            8940 non-null   object
#  5   estado            8940 non-null   object
#  6   regiao            8940 non-null   object
#  7   departamento      8940 non-null   object
#  8   tipo_produto      8940 non-null   object
#  9   vendas            8940 non-null   float64
#  10  quantidade        8940 non-null   int64
#  11  lucro             8940 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 838.2+ KB

# %%
df['data_pedido'] = pd.to_datetime(df['data_pedido'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8940 entries, 0 to 8939
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_pedido       8940 non-null   datetime64[ns]
#  1   modo_envio        8940 non-null   object
#  2   nome_cliente      8940 non-null   object
#  3   segmento_cliente  8940 non-null   object
#  4   cidade            8940 non-null   object
#  5   estado            8940 non-null   object
#  6   regiao            8940 non-null   object
#  7   departamento      8940 non-null   object
#  8   tipo_produto      8940 non-null   object
#  9   vendas            8940 non-null   float64
#  10  quantidade        8940 non-null   int64
#  11  lucro             8940 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 838.2+ KB

# %% [markdown]
# # Missão 1: Time de vendas
#
# Precisamos construir uma visualização para indicar os **10 maiores clientes por total de venda**.
#
# Com isso, a equipe de vendas pode pensar em estratégias para manter esses clientes comprando em nossa loja.

# %%
df_cliente_vendas = df.groupby(['nome_cliente'])['vendas'].sum().nlargest(10).copy()
df_cliente_vendas = df_cliente_vendas.reset_index()
df_cliente_vendas
# Out:
#             nome_cliente    vendas
# 0    Maria Luiza Almeida  64777.54
# 1        Ana Julia Pinto  51398.95
# 2            Ryan Farias  48178.94
# 3         Heitor da Mata  47610.85
# 4  Maria Clara Gonçalves  46946.42
# 5         Raquel Freitas  44826.26
# 6             Davi Ramos  43769.21
# 7            Amanda Melo  42354.27
# 8         Alexia Ribeiro  41238.84
# 9         Calebe Ribeiro  41056.70

# %%
df_cliente_vendas.columns = ['Clientes','Vendas']
df_cliente_vendas['Ranque'] = df_cliente_vendas.index + 1
df_cliente_vendas.set_index('Ranque', inplace = True)
df_cliente_vendas
# Out:
#                      Clientes    Vendas
# Ranque
# 1         Maria Luiza Almeida  64777.54
# 2             Ana Julia Pinto  51398.95
# 3                 Ryan Farias  48178.94
# 4              Heitor da Mata  47610.85
# 5       Maria Clara Gonçalves  46946.42
# 6              Raquel Freitas  44826.26
# 7                  Davi Ramos  43769.21
# 8                 Amanda Melo  42354.27
# 9              Alexia Ribeiro  41238.84
# 10             Calebe Ribeiro  41056.70

# %%
s = df_cliente_vendas.style
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_217a5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_217a5_level0_col0" class="col_heading level0 col0" >Clientes</th>
#       <th id="T_217a5_level0_col1" class="col_heading level0 col1" >Vendas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranque</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_217a5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_217a5_row0_col0" class="data row0 col0" >Maria Luiza Almeida</td>
#       <td id="T_217a5_row0_col1" class="data row0 col1" >64777.540000</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_217a5_row1_col0" class="data row1 col0" >Ana Julia Pinto</td>
#       <td id="T_217a5_row1_col1" class="data row1 col1" >51398.950000</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_217a5_row2_col0" class="data row2 col0" >Ryan Farias</td>
#       <td id="T_217a5_row2_col1" class="data row2 col1" >48178.940000</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_217a5_row3_col0" class="data row3 col0" >Heitor da Mata</td>
#       <td id="T_217a5_row3_col1" class="data row3 col1" >47610.850000</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_217a5_row4_col0" class="data row4 col0" >Maria Clara Gonçalves</td>
#       <td id="T_217a5_row4_col1" class="data row4 col1" >46946.420000</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_217a5_row5_col0" class="data row5 col0" >Raquel Freitas</td>
#       <td id="T_217a5_row5_col1" class="data row5 col1" >44826.260000</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_217a5_row6_col0" class="data row6 col0" >Davi Ramos</td>
#       <td id="T_217a5_row6_col1" class="data row6 col1" >43769.210000</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_217a5_row7_col0" class="data row7 col0" >Amanda Melo</td>
#       <td id="T_217a5_row7_col1" class="data row7 col1" >42354.270000</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_217a5_row8_col0" class="data row8 col0" >Alexia Ribeiro</td>
#       <td id="T_217a5_row8_col1" class="data row8 col1" >41238.840000</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_217a5_row9_col0" class="data row9 col0" >Calebe Ribeiro</td>
#       <td id="T_217a5_row9_col1" class="data row9 col1" >41056.700000</td>
#     </tr>
#   </tbody>
# </table>

# %%
s.format({'Vendas':'R$ {:,.2f}'})
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_217a5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_217a5_level0_col0" class="col_heading level0 col0" >Clientes</th>
#       <th id="T_217a5_level0_col1" class="col_heading level0 col1" >Vendas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranque</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_217a5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_217a5_row0_col0" class="data row0 col0" >Maria Luiza Almeida</td>
#       <td id="T_217a5_row0_col1" class="data row0 col1" >R$ 64,777.54</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_217a5_row1_col0" class="data row1 col0" >Ana Julia Pinto</td>
#       <td id="T_217a5_row1_col1" class="data row1 col1" >R$ 51,398.95</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_217a5_row2_col0" class="data row2 col0" >Ryan Farias</td>
#       <td id="T_217a5_row2_col1" class="data row2 col1" >R$ 48,178.94</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_217a5_row3_col0" class="data row3 col0" >Heitor da Mata</td>
#       <td id="T_217a5_row3_col1" class="data row3 col1" >R$ 47,610.85</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_217a5_row4_col0" class="data row4 col0" >Maria Clara Gonçalves</td>
#       <td id="T_217a5_row4_col1" class="data row4 col1" >R$ 46,946.42</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_217a5_row5_col0" class="data row5 col0" >Raquel Freitas</td>
#       <td id="T_217a5_row5_col1" class="data row5 col1" >R$ 44,826.26</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_217a5_row6_col0" class="data row6 col0" >Davi Ramos</td>
#       <td id="T_217a5_row6_col1" class="data row6 col1" >R$ 43,769.21</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_217a5_row7_col0" class="data row7 col0" >Amanda Melo</td>
#       <td id="T_217a5_row7_col1" class="data row7 col1" >R$ 42,354.27</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_217a5_row8_col0" class="data row8 col0" >Alexia Ribeiro</td>
#       <td id="T_217a5_row8_col1" class="data row8 col1" >R$ 41,238.84</td>
#     </tr>
#     <tr>
#       <th id="T_217a5_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_217a5_row9_col0" class="data row9 col0" >Calebe Ribeiro</td>
#       <td id="T_217a5_row9_col1" class="data row9 col1" >R$ 41,056.70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Missão 2: Time comercial
#
# Precisamos construir uma visualização que permita associar o **total ganho em vendas e o total lucrado por tipo de produto**.
#
# Isso vai permitir que o time comercial possa focar em estratégias para alavancar as rendas que ganham com cada tipo de produto vendido na loja.

# %%
df_venda_lucro = df.groupby(['tipo_produto'])[['vendas','lucro']].sum()
df_venda_lucro.index.name = 'tipo produto'
df_venda_lucro
# Out:
#                                vendas      lucro
# tipo produto
# decoração de jardim          82680.87   19880.86
# encanamentos                373224.39  -11243.39
# equipamentos de limpeza     542304.55   17448.30
# ferramentas                 995159.43   82042.91
# ferramentas automotivas     502109.33  126660.54
# ferramentas de jardinagem   648880.47  106408.80
# fertilizantes                53144.55   22509.86
# iluminação                  275229.82   40531.09
# materiais de paisagismo     150552.80   -3823.67
# materiais de revestimento   629656.41  -57737.23
# mobiliário de exterior      328932.37   53569.57
# mudas                         8811.69    2762.88
# pesticidas                  244958.41  106688.03
# peças de reposição          486907.88  182297.32
# pneus                      1022430.50  134923.09
# sementes                     39980.49   17730.06
# vasos                       696045.39   67887.28

# %%
estilo_produto = df_venda_lucro.style
estilo_produto
# Out:
# <style type="text/css">
# </style>
# <table id="T_2b558" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b558_level0_col0" class="col_heading level0 col0" >vendas</th>
#       <th id="T_2b558_level0_col1" class="col_heading level0 col1" >lucro</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b558_level0_row0" class="row_heading level0 row0" >decoração de jardim</th>
#       <td id="T_2b558_row0_col0" class="data row0 col0" >82680.870000</td>
#       <td id="T_2b558_row0_col1" class="data row0 col1" >19880.860000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row1" class="row_heading level0 row1" >encanamentos</th>
#       <td id="T_2b558_row1_col0" class="data row1 col0" >373224.390000</td>
#       <td id="T_2b558_row1_col1" class="data row1 col1" >-11243.390000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row2" class="row_heading level0 row2" >equipamentos de limpeza</th>
#       <td id="T_2b558_row2_col0" class="data row2 col0" >542304.550000</td>
#       <td id="T_2b558_row2_col1" class="data row2 col1" >17448.300000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row3" class="row_heading level0 row3" >ferramentas</th>
#       <td id="T_2b558_row3_col0" class="data row3 col0" >995159.430000</td>
#       <td id="T_2b558_row3_col1" class="data row3 col1" >82042.910000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row4" class="row_heading level0 row4" >ferramentas automotivas</th>
#       <td id="T_2b558_row4_col0" class="data row4 col0" >502109.330000</td>
#       <td id="T_2b558_row4_col1" class="data row4 col1" >126660.540000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row5" class="row_heading level0 row5" >ferramentas de jardinagem</th>
#       <td id="T_2b558_row5_col0" class="data row5 col0" >648880.470000</td>
#       <td id="T_2b558_row5_col1" class="data row5 col1" >106408.800000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row6" class="row_heading level0 row6" >fertilizantes</th>
#       <td id="T_2b558_row6_col0" class="data row6 col0" >53144.550000</td>
#       <td id="T_2b558_row6_col1" class="data row6 col1" >22509.860000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row7" class="row_heading level0 row7" >iluminação</th>
#       <td id="T_2b558_row7_col0" class="data row7 col0" >275229.820000</td>
#       <td id="T_2b558_row7_col1" class="data row7 col1" >40531.090000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row8" class="row_heading level0 row8" >materiais de paisagismo</th>
#       <td id="T_2b558_row8_col0" class="data row8 col0" >150552.800000</td>
#       <td id="T_2b558_row8_col1" class="data row8 col1" >-3823.670000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row9" class="row_heading level0 row9" >materiais de revestimento</th>
#       <td id="T_2b558_row9_col0" class="data row9 col0" >629656.410000</td>
#       <td id="T_2b558_row9_col1" class="data row9 col1" >-57737.230000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row10" class="row_heading level0 row10" >mobiliário de exterior</th>
#       <td id="T_2b558_row10_col0" class="data row10 col0" >328932.370000</td>
#       <td id="T_2b558_row10_col1" class="data row10 col1" >53569.570000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row11" class="row_heading level0 row11" >mudas</th>
#       <td id="T_2b558_row11_col0" class="data row11 col0" >8811.690000</td>
#       <td id="T_2b558_row11_col1" class="data row11 col1" >2762.880000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row12" class="row_heading level0 row12" >pesticidas</th>
#       <td id="T_2b558_row12_col0" class="data row12 col0" >244958.410000</td>
#       <td id="T_2b558_row12_col1" class="data row12 col1" >106688.030000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row13" class="row_heading level0 row13" >peças de reposição</th>
#       <td id="T_2b558_row13_col0" class="data row13 col0" >486907.880000</td>
#       <td id="T_2b558_row13_col1" class="data row13 col1" >182297.320000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row14" class="row_heading level0 row14" >pneus</th>
#       <td id="T_2b558_row14_col0" class="data row14 col0" >1022430.500000</td>
#       <td id="T_2b558_row14_col1" class="data row14 col1" >134923.090000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row15" class="row_heading level0 row15" >sementes</th>
#       <td id="T_2b558_row15_col0" class="data row15 col0" >39980.490000</td>
#       <td id="T_2b558_row15_col1" class="data row15 col1" >17730.060000</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row16" class="row_heading level0 row16" >vasos</th>
#       <td id="T_2b558_row16_col0" class="data row16 col0" >696045.390000</td>
#       <td id="T_2b558_row16_col1" class="data row16 col1" >67887.280000</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo_produto.format('R$ {:,.2f}')\
              .highlight_max(color='lightgreen')\
              .highlight_min(color='#F16165')
estilo_produto
# Out:
# <style type="text/css">
# #T_2b558_row9_col1, #T_2b558_row11_col0 {
#   background-color: #F16165;
# }
# #T_2b558_row13_col1, #T_2b558_row14_col0 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2b558" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b558_level0_col0" class="col_heading level0 col0" >vendas</th>
#       <th id="T_2b558_level0_col1" class="col_heading level0 col1" >lucro</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b558_level0_row0" class="row_heading level0 row0" >decoração de jardim</th>
#       <td id="T_2b558_row0_col0" class="data row0 col0" >R$ 82,680.87</td>
#       <td id="T_2b558_row0_col1" class="data row0 col1" >R$ 19,880.86</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row1" class="row_heading level0 row1" >encanamentos</th>
#       <td id="T_2b558_row1_col0" class="data row1 col0" >R$ 373,224.39</td>
#       <td id="T_2b558_row1_col1" class="data row1 col1" >R$ -11,243.39</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row2" class="row_heading level0 row2" >equipamentos de limpeza</th>
#       <td id="T_2b558_row2_col0" class="data row2 col0" >R$ 542,304.55</td>
#       <td id="T_2b558_row2_col1" class="data row2 col1" >R$ 17,448.30</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row3" class="row_heading level0 row3" >ferramentas</th>
#       <td id="T_2b558_row3_col0" class="data row3 col0" >R$ 995,159.43</td>
#       <td id="T_2b558_row3_col1" class="data row3 col1" >R$ 82,042.91</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row4" class="row_heading level0 row4" >ferramentas automotivas</th>
#       <td id="T_2b558_row4_col0" class="data row4 col0" >R$ 502,109.33</td>
#       <td id="T_2b558_row4_col1" class="data row4 col1" >R$ 126,660.54</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row5" class="row_heading level0 row5" >ferramentas de jardinagem</th>
#       <td id="T_2b558_row5_col0" class="data row5 col0" >R$ 648,880.47</td>
#       <td id="T_2b558_row5_col1" class="data row5 col1" >R$ 106,408.80</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row6" class="row_heading level0 row6" >fertilizantes</th>
#       <td id="T_2b558_row6_col0" class="data row6 col0" >R$ 53,144.55</td>
#       <td id="T_2b558_row6_col1" class="data row6 col1" >R$ 22,509.86</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row7" class="row_heading level0 row7" >iluminação</th>
#       <td id="T_2b558_row7_col0" class="data row7 col0" >R$ 275,229.82</td>
#       <td id="T_2b558_row7_col1" class="data row7 col1" >R$ 40,531.09</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row8" class="row_heading level0 row8" >materiais de paisagismo</th>
#       <td id="T_2b558_row8_col0" class="data row8 col0" >R$ 150,552.80</td>
#       <td id="T_2b558_row8_col1" class="data row8 col1" >R$ -3,823.67</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row9" class="row_heading level0 row9" >materiais de revestimento</th>
#       <td id="T_2b558_row9_col0" class="data row9 col0" >R$ 629,656.41</td>
#       <td id="T_2b558_row9_col1" class="data row9 col1" >R$ -57,737.23</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row10" class="row_heading level0 row10" >mobiliário de exterior</th>
#       <td id="T_2b558_row10_col0" class="data row10 col0" >R$ 328,932.37</td>
#       <td id="T_2b558_row10_col1" class="data row10 col1" >R$ 53,569.57</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row11" class="row_heading level0 row11" >mudas</th>
#       <td id="T_2b558_row11_col0" class="data row11 col0" >R$ 8,811.69</td>
#       <td id="T_2b558_row11_col1" class="data row11 col1" >R$ 2,762.88</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row12" class="row_heading level0 row12" >pesticidas</th>
#       <td id="T_2b558_row12_col0" class="data row12 col0" >R$ 244,958.41</td>
#       <td id="T_2b558_row12_col1" class="data row12 col1" >R$ 106,688.03</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row13" class="row_heading level0 row13" >peças de reposição</th>
#       <td id="T_2b558_row13_col0" class="data row13 col0" >R$ 486,907.88</td>
#       <td id="T_2b558_row13_col1" class="data row13 col1" >R$ 182,297.32</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row14" class="row_heading level0 row14" >pneus</th>
#       <td id="T_2b558_row14_col0" class="data row14 col0" >R$ 1,022,430.50</td>
#       <td id="T_2b558_row14_col1" class="data row14 col1" >R$ 134,923.09</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row15" class="row_heading level0 row15" >sementes</th>
#       <td id="T_2b558_row15_col0" class="data row15 col0" >R$ 39,980.49</td>
#       <td id="T_2b558_row15_col1" class="data row15 col1" >R$ 17,730.06</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row16" class="row_heading level0 row16" >vasos</th>
#       <td id="T_2b558_row16_col0" class="data row16 col0" >R$ 696,045.39</td>
#       <td id="T_2b558_row16_col1" class="data row16 col1" >R$ 67,887.28</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo_produto.format('R$ {:,.2f}').background_gradient(cmap='Greens')
estilo_produto
# Out:
# <style type="text/css">
# #T_2b558_row0_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_2b558_row0_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_2b558_row1_col0 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_2b558_row1_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_2b558_row2_col0 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_2b558_row2_col1, #T_2b558_row10_col0, #T_2b558_row15_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_2b558_row3_col0 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_2b558_row3_col1 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_2b558_row4_col0 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_2b558_row4_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_2b558_row5_col0 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_2b558_row5_col1, #T_2b558_row12_col1 {
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_2b558_row6_col0 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_2b558_row6_col1 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_2b558_row7_col0 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_2b558_row7_col1 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_2b558_row8_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_2b558_row8_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_2b558_row9_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_2b558_row9_col1, #T_2b558_row11_col0 {
#   background-color: #F16165;
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_2b558_row10_col1 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_2b558_row11_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_2b558_row12_col0 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_2b558_row13_col0 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_2b558_row13_col1, #T_2b558_row14_col0 {
#   background-color: lightgreen;
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2b558_row14_col1 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_2b558_row15_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_2b558_row16_col0 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_2b558_row16_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# </style>
# <table id="T_2b558" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b558_level0_col0" class="col_heading level0 col0" >vendas</th>
#       <th id="T_2b558_level0_col1" class="col_heading level0 col1" >lucro</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b558_level0_row0" class="row_heading level0 row0" >decoração de jardim</th>
#       <td id="T_2b558_row0_col0" class="data row0 col0" >R$ 82,680.87</td>
#       <td id="T_2b558_row0_col1" class="data row0 col1" >R$ 19,880.86</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row1" class="row_heading level0 row1" >encanamentos</th>
#       <td id="T_2b558_row1_col0" class="data row1 col0" >R$ 373,224.39</td>
#       <td id="T_2b558_row1_col1" class="data row1 col1" >R$ -11,243.39</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row2" class="row_heading level0 row2" >equipamentos de limpeza</th>
#       <td id="T_2b558_row2_col0" class="data row2 col0" >R$ 542,304.55</td>
#       <td id="T_2b558_row2_col1" class="data row2 col1" >R$ 17,448.30</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row3" class="row_heading level0 row3" >ferramentas</th>
#       <td id="T_2b558_row3_col0" class="data row3 col0" >R$ 995,159.43</td>
#       <td id="T_2b558_row3_col1" class="data row3 col1" >R$ 82,042.91</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row4" class="row_heading level0 row4" >ferramentas automotivas</th>
#       <td id="T_2b558_row4_col0" class="data row4 col0" >R$ 502,109.33</td>
#       <td id="T_2b558_row4_col1" class="data row4 col1" >R$ 126,660.54</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row5" class="row_heading level0 row5" >ferramentas de jardinagem</th>
#       <td id="T_2b558_row5_col0" class="data row5 col0" >R$ 648,880.47</td>
#       <td id="T_2b558_row5_col1" class="data row5 col1" >R$ 106,408.80</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row6" class="row_heading level0 row6" >fertilizantes</th>
#       <td id="T_2b558_row6_col0" class="data row6 col0" >R$ 53,144.55</td>
#       <td id="T_2b558_row6_col1" class="data row6 col1" >R$ 22,509.86</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row7" class="row_heading level0 row7" >iluminação</th>
#       <td id="T_2b558_row7_col0" class="data row7 col0" >R$ 275,229.82</td>
#       <td id="T_2b558_row7_col1" class="data row7 col1" >R$ 40,531.09</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row8" class="row_heading level0 row8" >materiais de paisagismo</th>
#       <td id="T_2b558_row8_col0" class="data row8 col0" >R$ 150,552.80</td>
#       <td id="T_2b558_row8_col1" class="data row8 col1" >R$ -3,823.67</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row9" class="row_heading level0 row9" >materiais de revestimento</th>
#       <td id="T_2b558_row9_col0" class="data row9 col0" >R$ 629,656.41</td>
#       <td id="T_2b558_row9_col1" class="data row9 col1" >R$ -57,737.23</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row10" class="row_heading level0 row10" >mobiliário de exterior</th>
#       <td id="T_2b558_row10_col0" class="data row10 col0" >R$ 328,932.37</td>
#       <td id="T_2b558_row10_col1" class="data row10 col1" >R$ 53,569.57</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row11" class="row_heading level0 row11" >mudas</th>
#       <td id="T_2b558_row11_col0" class="data row11 col0" >R$ 8,811.69</td>
#       <td id="T_2b558_row11_col1" class="data row11 col1" >R$ 2,762.88</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row12" class="row_heading level0 row12" >pesticidas</th>
#       <td id="T_2b558_row12_col0" class="data row12 col0" >R$ 244,958.41</td>
#       <td id="T_2b558_row12_col1" class="data row12 col1" >R$ 106,688.03</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row13" class="row_heading level0 row13" >peças de reposição</th>
#       <td id="T_2b558_row13_col0" class="data row13 col0" >R$ 486,907.88</td>
#       <td id="T_2b558_row13_col1" class="data row13 col1" >R$ 182,297.32</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row14" class="row_heading level0 row14" >pneus</th>
#       <td id="T_2b558_row14_col0" class="data row14 col0" >R$ 1,022,430.50</td>
#       <td id="T_2b558_row14_col1" class="data row14 col1" >R$ 134,923.09</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row15" class="row_heading level0 row15" >sementes</th>
#       <td id="T_2b558_row15_col0" class="data row15 col0" >R$ 39,980.49</td>
#       <td id="T_2b558_row15_col1" class="data row15 col1" >R$ 17,730.06</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row16" class="row_heading level0 row16" >vasos</th>
#       <td id="T_2b558_row16_col0" class="data row16 col0" >R$ 696,045.39</td>
#       <td id="T_2b558_row16_col1" class="data row16 col1" >R$ 67,887.28</td>
#     </tr>
#   </tbody>
# </table>

# %%
cabecalho = {
    'selector':'th',
    'props':'font-weight: bold; font-family: Arial; text-align: center; text-transform: capitalize;'
}
estilo_produto.set_table_styles([cabecalho], overwrite=False)
# Out:
# <style type="text/css">
# #T_2b558 th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: center;
#   text-transform: capitalize;
# }
# #T_2b558_row0_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_2b558_row0_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_2b558_row1_col0 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_2b558_row1_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_2b558_row2_col0 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_2b558_row2_col1, #T_2b558_row10_col0, #T_2b558_row15_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_2b558_row3_col0 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_2b558_row3_col1 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_2b558_row4_col0 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_2b558_row4_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_2b558_row5_col0 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_2b558_row5_col1, #T_2b558_row12_col1 {
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_2b558_row6_col0 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_2b558_row6_col1 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_2b558_row7_col0 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_2b558_row7_col1 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_2b558_row8_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_2b558_row8_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_2b558_row9_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_2b558_row9_col1, #T_2b558_row11_col0 {
#   background-color: #F16165;
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_2b558_row10_col1 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_2b558_row11_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_2b558_row12_col0 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_2b558_row13_col0 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_2b558_row13_col1, #T_2b558_row14_col0 {
#   background-color: lightgreen;
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2b558_row14_col1 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_2b558_row15_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_2b558_row16_col0 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_2b558_row16_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# </style>
# <table id="T_2b558" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b558_level0_col0" class="col_heading level0 col0" >vendas</th>
#       <th id="T_2b558_level0_col1" class="col_heading level0 col1" >lucro</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b558_level0_row0" class="row_heading level0 row0" >decoração de jardim</th>
#       <td id="T_2b558_row0_col0" class="data row0 col0" >R$ 82,680.87</td>
#       <td id="T_2b558_row0_col1" class="data row0 col1" >R$ 19,880.86</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row1" class="row_heading level0 row1" >encanamentos</th>
#       <td id="T_2b558_row1_col0" class="data row1 col0" >R$ 373,224.39</td>
#       <td id="T_2b558_row1_col1" class="data row1 col1" >R$ -11,243.39</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row2" class="row_heading level0 row2" >equipamentos de limpeza</th>
#       <td id="T_2b558_row2_col0" class="data row2 col0" >R$ 542,304.55</td>
#       <td id="T_2b558_row2_col1" class="data row2 col1" >R$ 17,448.30</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row3" class="row_heading level0 row3" >ferramentas</th>
#       <td id="T_2b558_row3_col0" class="data row3 col0" >R$ 995,159.43</td>
#       <td id="T_2b558_row3_col1" class="data row3 col1" >R$ 82,042.91</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row4" class="row_heading level0 row4" >ferramentas automotivas</th>
#       <td id="T_2b558_row4_col0" class="data row4 col0" >R$ 502,109.33</td>
#       <td id="T_2b558_row4_col1" class="data row4 col1" >R$ 126,660.54</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row5" class="row_heading level0 row5" >ferramentas de jardinagem</th>
#       <td id="T_2b558_row5_col0" class="data row5 col0" >R$ 648,880.47</td>
#       <td id="T_2b558_row5_col1" class="data row5 col1" >R$ 106,408.80</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row6" class="row_heading level0 row6" >fertilizantes</th>
#       <td id="T_2b558_row6_col0" class="data row6 col0" >R$ 53,144.55</td>
#       <td id="T_2b558_row6_col1" class="data row6 col1" >R$ 22,509.86</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row7" class="row_heading level0 row7" >iluminação</th>
#       <td id="T_2b558_row7_col0" class="data row7 col0" >R$ 275,229.82</td>
#       <td id="T_2b558_row7_col1" class="data row7 col1" >R$ 40,531.09</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row8" class="row_heading level0 row8" >materiais de paisagismo</th>
#       <td id="T_2b558_row8_col0" class="data row8 col0" >R$ 150,552.80</td>
#       <td id="T_2b558_row8_col1" class="data row8 col1" >R$ -3,823.67</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row9" class="row_heading level0 row9" >materiais de revestimento</th>
#       <td id="T_2b558_row9_col0" class="data row9 col0" >R$ 629,656.41</td>
#       <td id="T_2b558_row9_col1" class="data row9 col1" >R$ -57,737.23</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row10" class="row_heading level0 row10" >mobiliário de exterior</th>
#       <td id="T_2b558_row10_col0" class="data row10 col0" >R$ 328,932.37</td>
#       <td id="T_2b558_row10_col1" class="data row10 col1" >R$ 53,569.57</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row11" class="row_heading level0 row11" >mudas</th>
#       <td id="T_2b558_row11_col0" class="data row11 col0" >R$ 8,811.69</td>
#       <td id="T_2b558_row11_col1" class="data row11 col1" >R$ 2,762.88</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row12" class="row_heading level0 row12" >pesticidas</th>
#       <td id="T_2b558_row12_col0" class="data row12 col0" >R$ 244,958.41</td>
#       <td id="T_2b558_row12_col1" class="data row12 col1" >R$ 106,688.03</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row13" class="row_heading level0 row13" >peças de reposição</th>
#       <td id="T_2b558_row13_col0" class="data row13 col0" >R$ 486,907.88</td>
#       <td id="T_2b558_row13_col1" class="data row13 col1" >R$ 182,297.32</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row14" class="row_heading level0 row14" >pneus</th>
#       <td id="T_2b558_row14_col0" class="data row14 col0" >R$ 1,022,430.50</td>
#       <td id="T_2b558_row14_col1" class="data row14 col1" >R$ 134,923.09</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row15" class="row_heading level0 row15" >sementes</th>
#       <td id="T_2b558_row15_col0" class="data row15 col0" >R$ 39,980.49</td>
#       <td id="T_2b558_row15_col1" class="data row15 col1" >R$ 17,730.06</td>
#     </tr>
#     <tr>
#       <th id="T_2b558_level0_row16" class="row_heading level0 row16" >vasos</th>
#       <td id="T_2b558_row16_col0" class="data row16 col0" >R$ 696,045.39</td>
#       <td id="T_2b558_row16_col1" class="data row16 col1" >R$ 67,887.28</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Missão 3: Time de logística
#
# Precisamos construir uma visualização que permita entender a **distribuição de pedidos por região do Brasil**.
#
# Isso vai permitir que o time logística entenda onde é mais interessante focar material e pessoas.

# %%
df_regiao = pd.DataFrame(df['regiao'].value_counts())
df_regiao.columns = ['N° pedidos']
df_regiao
# Out:
#               N° pedidos
# regiao
# Sudeste             4470
# Nordeste            2075
# Centro-Oeste         983
# Norte                779
# Sul                  633

# %%
df_regiao.index.name = 'Regiao'

# %%
import numpy as np

# %%
porcentagem = df_regiao['N° pedidos'].to_numpy()
porcentagem = 100 * porcentagem/porcentagem.sum()
porcentagem
# Out:
# array([50.        , 23.21029083, 10.99552573,  8.71364653,  7.08053691])

# %%
df_regiao['Porcentagem regiao'] = porcentagem
df_regiao
# Out:
#               N° pedidos  Porcentagem regiao
# Regiao
# Sudeste             4470           50.000000
# Nordeste            2075           23.210291
# Centro-Oeste         983           10.995526
# Norte                779            8.713647
# Sul                  633            7.080537

# %%
estilo_regiao = df_regiao.style
estilo_regiao
# Out:
# <style type="text/css">
# </style>
# <table id="T_ea074" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea074_level0_col0" class="col_heading level0 col0" >N° pedidos</th>
#       <th id="T_ea074_level0_col1" class="col_heading level0 col1" >Porcentagem regiao</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Regiao</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea074_level0_row0" class="row_heading level0 row0" >Sudeste</th>
#       <td id="T_ea074_row0_col0" class="data row0 col0" >4470</td>
#       <td id="T_ea074_row0_col1" class="data row0 col1" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ea074_level0_row1" class="row_heading level0 row1" >Nordeste</th>
#       <td id="T_ea074_row1_col0" class="data row1 col0" >2075</td>
#       <td id="T_ea074_row1_col1" class="data row1 col1" >23.210291</td>
#     </tr>
#     <tr>
#       <th id="T_ea074_level0_row2" class="row_heading level0 row2" >Centro-Oeste</th>
#       <td id="T_ea074_row2_col0" class="data row2 col0" >983</td>
#       <td id="T_ea074_row2_col1" class="data row2 col1" >10.995526</td>
#     </tr>
#     <tr>
#       <th id="T_ea074_level0_row3" class="row_heading level0 row3" >Norte</th>
#       <td id="T_ea074_row3_col0" class="data row3 col0" >779</td>
#       <td id="T_ea074_row3_col1" class="data row3 col1" >8.713647</td>
#     </tr>
#     <tr>
#       <th id="T_ea074_level0_row4" class="row_heading level0 row4" >Sul</th>
#       <td id="T_ea074_row4_col0" class="data row4 col0" >633</td>
#       <td id="T_ea074_row4_col1" class="data row4 col1" >7.080537</td>
#     </tr>
#   </tbody>
# </table>

# %%
cabecalho = {
    'selector': 'th',
    'props':'font-weight: bold; font-family: Arial; text-align: right; background-color: white'
}
celulas = {
    'selector': 'td',
    'props': 'background-color: white;'
}

estilo_regiao.set_table_styles([cabecalho,celulas])
# Out:
# <style type="text/css">
# #T_ea074 th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
#   background-color: white;
# }
# #T_ea074 td {
#   background-color: white;
# }
# </style>
# <table id="T_ea074" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea074_level0_col0" class="col_heading level0 col0" >N° pedidos</th>
#       <th id="T_ea074_level0_col1" class="col_heading level0 col1" >Porcentagem regiao</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Regiao</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea074_level0_row0" class="row_heading level0 row0" >Sudeste</th>
#       <td id="T_ea074_row0_col0" class="data row0 col0" >4470</td>
#       <td id="T_ea074_row0_col1" class="data row0 col1" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ea074_level0_row1" class="row_heading level0 row1" >Nordeste</th>
#       <td id="T_ea074_row1_col0" class="data row1 col0" >2075</td>
#       <td id="T_ea074_row1_col1" class="data row1 col1" >23.210291</td>
#     </tr>
#     <tr>
#       <th id="T_ea074_level0_row2" class="row_heading level0 row2" >Centro-Oeste</th>
#       <td id="T_ea074_row2_col0" class="data row2 col0" >983</td>
#       <td id="T_ea074_row2_col1" class="data row2 col1" >10.995526</td>
#     </tr>
#     <tr>
#       <th id="T_ea074_level0_row3" class="row_heading level0 row3" >Norte</th>
#       <td id="T_ea074_row3_col0" class="data row3 col0" >779</td>
#       <td id="T_ea074_row3_col1" class="data row3 col1" >8.713647</td>
#     </tr>
#     <tr>
#       <th id="T_ea074_level0_row4" class="row_heading level0 row4" >Sul</th>
#       <td id="T_ea074_row4_col0" class="data row4 col0" >633</td>
#       <td id="T_ea074_row4_col1" class="data row4 col1" >7.080537</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo_regiao.format({'Porcentagem regiao':'{:.2f} %'})\
             .bar(subset='Porcentagem regiao', vmin=0, vmax=100.0, color='#9CD33B')
# Out:
# <style type="text/css">
# #T_ea074 th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
#   background-color: white;
# }
# #T_ea074 td {
#   background-color: white;
# }
# #T_ea074_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 50.0%, transparent 50.0%);
# }
# #T_ea074_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 23.2%, transparent 23.2%);
# }
# #T_ea074_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 11.0%, transparent 11.0%);
# }
# #T_ea074_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 8.7%, transparent 8.7%);
# }
# #T_ea074_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 7.1%, transparent 7.1%);
# }
# </style>
# <table id="T_ea074" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea074_level0_col0" class="col_heading level0 col0" >N° pedidos</th>
#       <th id="T_ea074_level0_col1" class="col_heading level0 col1" >Porcentagem regiao</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Regiao</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea074_level0_row0" class="row_heading level0 row0" >Sudeste</th>
#       <td id="T_ea074_row0_col0" class="data row0 col0" >4470</td>
#       <td id="T_ea074_row0_col1" class="data row0 col1" >50.00 %</td>
#     </tr>
#     <tr>
#       <th id="T_ea074_level0_row1" class="row_heading level0 row1" >Nordeste</th>
#       <td id="T_ea074_row1_col0" class="data row1 col0" >2075</td>
#       <td id="T_ea074_row1_col1" class="data row1 col1" >23.21 %</td>
#     </tr>
#     <tr>
#       <th id="T_ea074_level0_row2" class="row_heading level0 row2" >Centro-Oeste</th>
#       <td id="T_ea074_row2_col0" class="data row2 col0" >983</td>
#       <td id="T_ea074_row2_col1" class="data row2 col1" >11.00 %</td>
#     </tr>
#     <tr>
#       <th id="T_ea074_level0_row3" class="row_heading level0 row3" >Norte</th>
#       <td id="T_ea074_row3_col0" class="data row3 col0" >779</td>
#       <td id="T_ea074_row3_col1" class="data row3 col1" >8.71 %</td>
#     </tr>
#     <tr>
#       <th id="T_ea074_level0_row4" class="row_heading level0 row4" >Sul</th>
#       <td id="T_ea074_row4_col0" class="data row4 col0" >633</td>
#       <td id="T_ea074_row4_col1" class="data row4 col1" >7.08 %</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Missão 4: Time de logística
#
# Novamente o time de logística deseja repensar sua estrutura e organização de fornecimento de produtos e para isso, foi pensada em uma visualização que permita identificar padrão de **quantidade de produtos solicitados por mês por departamento**.

# %% [markdown]
# # Missão 5: Relatório de performance
#
# O relatório de performance é um documento muito importante para a empresa. Nele, todos que trabalham na loja podem entender como anda a empresa. Por conta disso, tabelas bem construídas são essenciais para mostrar os dados da melhor forma.
#
# Portanto, precisamos construir uma visualização que permita entender a **relação entre tipos de clientes e modo de envio de produtos de acordo com as vendas**. Com isso, será possível destacar no relatório qual o modo de envio e quais tipos de modo de envio mais geraram ganho em vendas.
